# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustafa-Dara-Ozevin/Reinforcement_Learning_with_gym/blob/master/CartPoleREINFORCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install box2d-py
# !pip install Box2D
# !pip install tensorboardx
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !pip install ptan
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# Out:
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/06/bd/6cdc3fd994b0649dcf5d9bad85bd9e26172308bbe9a421bfc6fdbf5081a6/box2d_py-2.3.8-cp36-cp36m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 7.0MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Collecting Box2D
#   Downloading https://files.pythonhosted.org/packages/a9/0b/d48d42dd9e19ce83a3fb4eee074e785b6c6ea612a2244dc2ef69427d338b/Box2D-2.3.10-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 6.4MB/s
# Installing collected packages: Box2D
# Successfully installed Box2D-2.3.10
# Collecting tensorboardx
#   Downloading https://files.pythonhosted.org/packages/35/f1/5843425495765c8c2dd0784a851a93ef204d314fc87bcc2bbb9f662a3ad1/tensorboardX-2.0-py2.py3-none-any.whl (195kB)
#      |████████████████████████████████| 204kB 7.2MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardx) (3.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardx) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardx) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardx) (47.3.1)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-2.0
# Collecting ptan
#   Downloading https://files.pythonhosted.org/packages/91/cb/57f6d86625f2b24c008b0524ca29559683aa75d00afa38b6b44d7fcad25b/ptan-0.6.tar.gz
# Collecting torch==1.3.0
#   Downloading https://files.pythonhosted.org/packages/ae/05/50a05de5337f7a924bb8bd70c6936230642233e424d6a9747ef1cfbde353/torch-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (773.1MB)
#      |████████████████████████████████| 773.1MB 24kB/s
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from ptan) (0.17.2)
# Requirement already satisfied: atari-py in /usr/local/lib/python3.6/dist-packages (from ptan) (0.2.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ptan) (1.18.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from ptan) (4.1.2.30)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->ptan) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->ptan) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->ptan) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from atari-py->ptan) (1.12.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->ptan) (0.16.0)
# Building wheels for collected packages: ptan
#   Building wheel for ptan (setup.py) ... done
#   Created wheel for ptan: filename=ptan-0.6-cp36-none-any.whl size=23502 sha256=1aee60293979e8b4af7156b8a0b329ec202bdb9ea3935a65c90dcc8be4611571
#   Stored in directory: /root/.cache/pip/wheels/f0/4b/2f/9a45fd39b0a614a2716bc6128a7f1adb4647f323a2d90783f2
# Successfully built ptan
# ERROR: torchvision 0.6.1+cu101 has requirement torch==1.5.1, but you'll have torch 1.3.0 which is incompatible.
# Installing collected packages: torch, ptan
#   Found existing installation: torch 1.5.1+cu101
#     Uninstalling torch-1.5.1+cu101:
#       Successfully uninstalled torch-1.5.1+cu101
# Successfully installed ptan-0.6 torch-1.3.0

# %%
import torch
import ptan
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
 
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import tensorflow as tf
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
 
from IPython import display as ipythondisplay
import collections
import time
import numpy as np
from tensorboardX import SummaryWriter
 
# %load_ext tensorboard
 
ENV_NAME = 'CartPole-v0'
GAMMA = 0.99
LEARNING_RATE = 0.01
EPISODES_TO_TRAIN = 4
SHOW_EVERY = 10_000
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
class PGN(nn.Module):
  def __init__(self, input_size, n_actions):
    super(PGN, self).__init__()
    self.net = nn.Sequential(
        nn.Linear(input_size,256),
        nn.ReLU(),
        nn.Linear(256, n_actions)
    )

  def forward(self, x):
    return self.net(x)


def calc_qvals(rewards):
  res = []
  sum_r = 0.0
  for r in reversed(rewards):
    sum_r *= GAMMA
    sum_r += r 
    res.append(sum_r)
  return list(reversed(res))

if __name__ == '__main__':
    env = wrap_env(gym.make(ENV_NAME))
    
    writer = SummaryWriter(comment='-CartPole-reinforce')
    net = PGN(env.observation_space.shape[0], env.action_space.n)

    agent = ptan.agent.PolicyAgent(net, preprocessor=ptan.agent.float32_preprocessor,
                                    apply_softmax=True)
    exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=GAMMA)

    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)

    total_rewards = []
    step_idx = 0
    done_episodes = 0

    batch_episodes = 0
    batch_states, batch_actions, batch_qvals = [], [], []
    cur_rewards = []

    for step_idx, exp in enumerate(exp_source):
        batch_states.append(exp.state)
        batch_actions.append(int(exp.action))
        cur_rewards.append(exp.reward)

        if step_idx % SHOW_EVERY == 0:
          env.render()
          show_video()

        if exp.last_state is None:
            batch_qvals.extend(calc_qvals(cur_rewards))
            cur_rewards.clear()
            batch_episodes += 1

        # handle new rewards
        new_rewards = exp_source.pop_total_rewards()
        if new_rewards:
            done_episodes += 1
            reward = new_rewards[0]
            total_rewards.append(reward)
            mean_rewards = float(np.mean(total_rewards[-100:]))
            print("%d: reward: %6.2f, mean_100: %6.2f, episodes: %d" % (
                step_idx, reward, mean_rewards, done_episodes))
            writer.add_scalar("reward", reward, step_idx)
            writer.add_scalar("reward_100", mean_rewards, step_idx)
            writer.add_scalar("episodes", done_episodes, step_idx)
            if mean_rewards > 195:
                print("Solved in %d steps and %d episodes!" % (step_idx, done_episodes))
                break

        if batch_episodes < EPISODES_TO_TRAIN:
            continue

        optimizer.zero_grad()
        states_v = torch.FloatTensor(batch_states)
        batch_actions_t = torch.LongTensor(batch_actions)
        batch_qvals_v = torch.FloatTensor(batch_qvals)

        logits_v = net(states_v)
        log_prob_v = F.log_softmax(logits_v, dim=1)
        log_prob_actions_v = batch_qvals_v * log_prob_v[range(len(batch_states)), batch_actions_t]
        loss_v = -log_prob_actions_v.mean()

        loss_v.backward()
        optimizer.step()

        batch_episodes = 0
        batch_states.clear()
        batch_actions.clear()
        batch_qvals.clear()

    writer.close()
    env.close()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64," type="video/mp4" />
#              </video>
# 10: reward:  10.00, mean_100:  10.00, episodes: 1
# 25: reward:  15.00, mean_100:  12.50, episodes: 2
# 55: reward:  30.00, mean_100:  18.33, episodes: 3
# 68: reward:  13.00, mean_100:  17.00, episodes: 4
# 86: reward:  18.00, mean_100:  17.20, episodes: 5
# 99: reward:  13.00, mean_100:  16.50, episodes: 6
# 112: reward:  13.00, mean_100:  16.00, episodes: 7
# 138: reward:  26.00, mean_100:  17.25, episodes: 8
# 156: reward:  18.00, mean_100:  17.33, episodes: 9
# 179: reward:  23.00, mean_100:  17.90, episodes: 10
# 193: reward:  14.00, mean_100:  17.55, episodes: 11
# 205: reward:  12.00, mean_100:  17.08, episodes: 12
# 231: reward:  26.00, mean_100:  17.77, episodes: 13
# 252: reward:  21.00, mean_100:  18.00, episodes: 14
# 281: reward:  29.00, mean_100:  18.73, episodes: 15
# 295: reward:  14.00, mean_100:  18.44, episodes: 16
# 364: reward:  69.00, mean_100:  21.41, episodes: 17
# 382: reward:  18.00, mean_100:  21.22, episodes: 18
# 416: reward:  34.00, mean_100:  21.89, episodes: 19
# 430: reward:  14.00, mean_100:  21.50, episodes: 20
# 480: reward:  50.00, mean_100:  22.86, episodes: 21
# 491: reward:  11.00, mean_100:  22.32, episodes: 22
# 539: reward:  48.00, mean_100:  23.43, episodes: 23
# 568: reward:  29.00, mean_100:  23.67, episodes: 24
# 596: reward:  28.00, mean_100:  23.84, episodes: 25
# 639: reward:  43.00, mean_100:  24.58, episodes: 26
# 734: reward:  95.00, mean_100:  27.19, episodes: 27
# 783: reward:  49.00, mean_100:  27.96, episodes: 28
# 828: reward:  45.00, mean_100:  28.55, episodes: 29
# 843: reward:  15.00, mean_100:  28.10, episodes: 30
# 958: reward: 115.00, mean_100:  30.90, episodes: 31
# 1095: reward: 137.00, mean_100:  34.22, episodes: 32
# 1145: reward:  50.00, mean_100:  34.70, episodes: 33
# 1220: reward:  75.00, mean_100:  35.88, episodes: 34
# 1263: reward:  43.00, mean_100:  36.09, episodes: 35
# 1334: reward:  71.00, mean_100:  37.06, episodes: 36
# 1392: reward:  58.00, mean_100:  37.62, episodes: 37
# 1473: reward:  81.00, mean_100:  38.76, episodes: 38
# 1545: reward:  72.00, mean_100:  39.62, episodes: 39
# 1609: reward:  64.00, mean_100:  40.23, episodes: 40
# 1668: reward:  59.00, mean_100:  40.68, episodes: 41
# 1729: reward:  61.00, mean_100:  41.17, episodes: 42
# 1807: reward:  78.00, mean_100:  42.02, episodes: 43
# 1844: reward:  37.00, mean_100:  41.91, episodes: 44
# 1957: reward: 113.00, mean_100:  43.49, episodes: 45
# 2059: reward: 102.00, mean_100:  44.76, episodes: 46
# 2128: reward:  69.00, mean_100:  45.28, episodes: 47
# 2195: reward:  67.00, mean_100:  45.73, episodes: 48
# 2324: reward: 129.00, mean_100:  47.43, episodes: 49
# 2380: reward:  56.00, mean_100:  47.60, episodes: 50
# 2425: reward:  45.00, mean_100:  47.55, episodes: 51
# 2550: reward: 125.00, mean_100:  49.04, episodes: 52
# 2641: reward:  91.00, mean_100:  49.83, episodes: 53
# 2727: reward:  86.00, mean_100:  50.50, episodes: 54
# 2774: reward:  47.00, mean_100:  50.44, episodes: 55
# 2856: reward:  82.00, mean_100:  51.00, episodes: 56
# 2911: reward:  55.00, mean_100:  51.07, episodes: 57
# 3033: reward: 122.00, mean_100:  52.29, episodes: 58
# 3107: reward:  74.00, mean_100:  52.66, episodes: 59
# 3218: reward: 111.00, mean_100:  53.63, episodes: 60
# 3327: reward: 109.00, mean_100:  54.54, episodes: 61
# 3527: reward: 200.00, mean_100:  56.89, episodes: 62
# 3697: reward: 170.00, mean_100:  58.68, episodes: 63
# 3759: reward:  62.00, mean_100:  58.73, episodes: 64
# 3811: reward:  52.00, mean_100:  58.63, episodes: 65
# 3884: reward:  73.00, mean_100:  58.85, episodes: 66
# 3928: reward:  44.00, mean_100:  58.63, episodes: 67
# 4049: reward: 121.00, mean_100:  59.54, episodes: 68
# 4136: reward:  87.00, mean_100:  59.94, episodes: 69
# 4245: reward: 109.00, mean_100:  60.64, episodes: 70
# 4363: reward: 118.00, mean_100:  61.45, episodes: 71
# 4453: reward:  90.00, mean_100:  61.85, episodes: 72
# 4505: reward:  52.00, mean_100:  61.71, episodes: 73
# 4560: reward:  55.00, mean_100:  61.62, episodes: 74
# 4620: reward:  60.00, mean_100:  61.60, episodes: 75
# 4676: reward:  56.00, mean_100:  61.53, episodes: 76
# 4742: reward:  66.00, mean_100:  61.58, episodes: 77
# 4830: reward:  88.00, mean_100:  61.92, episodes: 78
# 4886: reward:  56.00, mean_100:  61.85, episodes: 79
# 4913: reward:  27.00, mean_100:  61.41, episodes: 80
# 5025: reward: 112.00, mean_100:  62.04, episodes: 81
# 5080: reward:  55.00, mean_100:  61.95, episodes: 82
# 5134: reward:  54.00, mean_100:  61.86, episodes: 83
# 5221: reward:  87.00, mean_100:  62.15, episodes: 84
# 5301: reward:  80.00, mean_100:  62.36, episodes: 85
# 5333: reward:  32.00, mean_100:  62.01, episodes: 86
# 5397: reward:  64.00, mean_100:  62.03, episodes: 87
# 5445: reward:  48.00, mean_100:  61.88, episodes: 88
# 5533: reward:  88.00, mean_100:  62.17, episodes: 89
# 5583: reward:  50.00, mean_100:  62.03, episodes: 90
# 5663: reward:  80.00, mean_100:  62.23, episodes: 91
# 5726: reward:  63.00, mean_100:  62.24, episodes: 92
# 5816: reward:  90.00, mean_100:  62.54, episodes: 93
# 5957: reward: 141.00, mean_100:  63.37, episodes: 94
# 6082: reward: 125.00, mean_100:  64.02, episodes: 95
# 6156: reward:  74.00, mean_100:  64.12, episodes: 96
# 6283: reward: 127.00, mean_100:  64.77, episodes: 97
# 6343: reward:  60.00, mean_100:  64.72, episodes: 98
# 6529: reward: 186.00, mean_100:  65.95, episodes: 99
# 6639: reward: 110.00, mean_100:  66.39, episodes: 100
# 6737: reward:  98.00, mean_100:  67.27, episodes: 101
# 6937: reward: 200.00, mean_100:  69.12, episodes: 102
# 7021: reward:  84.00, mean_100:  69.66, episodes: 103
# 7118: reward:  97.00, mean_100:  70.50, episodes: 104
# 7249: reward: 131.00, mean_100:  71.63, episodes: 105
# 7392: reward: 143.00, mean_100:  72.93, episodes: 106
# 7584: reward: 192.00, mean_100:  74.72, episodes: 107
# 7722: reward: 138.00, mean_100:  75.84, episodes: 108
# 7922: reward: 200.00, mean_100:  77.66, episodes: 109
# 8122: reward: 200.00, mean_100:  79.43, episodes: 110
# 8322: reward: 200.00, mean_100:  81.29, episodes: 111
# 8522: reward: 200.00, mean_100:  83.17, episodes: 112
# 8722: reward: 200.00, mean_100:  84.91, episodes: 113
# 8922: reward: 200.00, mean_100:  86.70, episodes: 114
# 9122: reward: 200.00, mean_100:  88.41, episodes: 115
# 9322: reward: 200.00, mean_100:  90.27, episodes: 116
# 9511: reward: 189.00, mean_100:  91.47, episodes: 117
# 9711: reward: 200.00, mean_100:  93.29, episodes: 118
# 9911: reward: 200.00, mean_100:  94.95, episodes: 119
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 10111: reward: 200.00, mean_100:  96.81, episodes: 120
# 10264: reward: 153.00, mean_100:  97.84, episodes: 121
# 10434: reward: 170.00, mean_100:  99.43, episodes: 122
# 10596: reward: 162.00, mean_100: 100.57, episodes: 123
# 10767: reward: 171.00, mean_100: 101.99, episodes: 124
# 10876: reward: 109.00, mean_100: 102.80, episodes: 125
# 10999: reward: 123.00, mean_100: 103.60, episodes: 126
# 11109: reward: 110.00, mean_100: 103.75, episodes: 127
# 11238: reward: 129.00, mean_100: 104.55, episodes: 128
# 11344: reward: 106.00, mean_100: 105.16, episodes: 129
# 11458: reward: 114.00, mean_100: 106.15, episodes: 130
# 11518: reward:  60.00, mean_100: 105.60, episodes: 131
# 11628: reward: 110.00, mean_100: 105.33, episodes: 132
# 11706: reward:  78.00, mean_100: 105.61, episodes: 133
# 11792: reward:  86.00, mean_100: 105.72, episodes: 134
# 11900: reward: 108.00, mean_100: 106.37, episodes: 135
# 11967: reward:  67.00, mean_100: 106.33, episodes: 136
# 12013: reward:  46.00, mean_100: 106.21, episodes: 137
# 12100: reward:  87.00, mean_100: 106.27, episodes: 138
# 12142: reward:  42.00, mean_100: 105.97, episodes: 139
# 12190: reward:  48.00, mean_100: 105.81, episodes: 140
# 12261: reward:  71.00, mean_100: 105.93, episodes: 141
# 12310: reward:  49.00, mean_100: 105.81, episodes: 142
# 12368: reward:  58.00, mean_100: 105.61, episodes: 143
# 12427: reward:  59.00, mean_100: 105.83, episodes: 144
# 12495: reward:  68.00, mean_100: 105.38, episodes: 145
# 12562: reward:  67.00, mean_100: 105.03, episodes: 146
# 12646: reward:  84.00, mean_100: 105.18, episodes: 147
# 12714: reward:  68.00, mean_100: 105.19, episodes: 148
# 12769: reward:  55.00, mean_100: 104.45, episodes: 149
# 12822: reward:  53.00, mean_100: 104.42, episodes: 150
# 12868: reward:  46.00, mean_100: 104.43, episodes: 151
# 12920: reward:  52.00, mean_100: 103.70, episodes: 152
# 12973: reward:  53.00, mean_100: 103.32, episodes: 153
# 13051: reward:  78.00, mean_100: 103.24, episodes: 154
# 13120: reward:  69.00, mean_100: 103.46, episodes: 155
# 13220: reward: 100.00, mean_100: 103.64, episodes: 156
# 13315: reward:  95.00, mean_100: 104.04, episodes: 157
# 13390: reward:  75.00, mean_100: 103.57, episodes: 158
# 13472: reward:  82.00, mean_100: 103.65, episodes: 159
# 13531: reward:  59.00, mean_100: 103.13, episodes: 160
# 13607: reward:  76.00, mean_100: 102.80, episodes: 161
# 13693: reward:  86.00, mean_100: 101.66, episodes: 162
# 13770: reward:  77.00, mean_100: 100.73, episodes: 163
# 13854: reward:  84.00, mean_100: 100.95, episodes: 164
# 13960: reward: 106.00, mean_100: 101.49, episodes: 165
# 14033: reward:  73.00, mean_100: 101.49, episodes: 166
# 14151: reward: 118.00, mean_100: 102.23, episodes: 167
# 14260: reward: 109.00, mean_100: 102.11, episodes: 168
# 14374: reward: 114.00, mean_100: 102.38, episodes: 169
# 14475: reward: 101.00, mean_100: 102.30, episodes: 170
# 14605: reward: 130.00, mean_100: 102.42, episodes: 171
# 14695: reward:  90.00, mean_100: 102.42, episodes: 172
# 14808: reward: 113.00, mean_100: 103.03, episodes: 173
# 14921: reward: 113.00, mean_100: 103.61, episodes: 174
# 15064: reward: 143.00, mean_100: 104.44, episodes: 175
# 15186: reward: 122.00, mean_100: 105.10, episodes: 176
# 15386: reward: 200.00, mean_100: 106.44, episodes: 177
# 15561: reward: 175.00, mean_100: 107.31, episodes: 178
# 15683: reward: 122.00, mean_100: 107.97, episodes: 179
# 15793: reward: 110.00, mean_100: 108.80, episodes: 180
# 15993: reward: 200.00, mean_100: 109.68, episodes: 181
# 16111: reward: 118.00, mean_100: 110.31, episodes: 182
# 16311: reward: 200.00, mean_100: 111.77, episodes: 183
# 16511: reward: 200.00, mean_100: 112.90, episodes: 184
# 16702: reward: 191.00, mean_100: 114.01, episodes: 185
# 16901: reward: 199.00, mean_100: 115.68, episodes: 186
# 17101: reward: 200.00, mean_100: 117.04, episodes: 187
# 17253: reward: 152.00, mean_100: 118.08, episodes: 188
# 17453: reward: 200.00, mean_100: 119.20, episodes: 189
# 17653: reward: 200.00, mean_100: 120.70, episodes: 190
# 17853: reward: 200.00, mean_100: 121.90, episodes: 191
# 18053: reward: 200.00, mean_100: 123.27, episodes: 192
# 18253: reward: 200.00, mean_100: 124.37, episodes: 193
# 18453: reward: 200.00, mean_100: 124.96, episodes: 194
# 18653: reward: 200.00, mean_100: 125.71, episodes: 195
# 18853: reward: 200.00, mean_100: 126.97, episodes: 196
# 19051: reward: 198.00, mean_100: 127.68, episodes: 197
# 19251: reward: 200.00, mean_100: 129.08, episodes: 198
# 19451: reward: 200.00, mean_100: 129.22, episodes: 199
# 19651: reward: 200.00, mean_100: 130.12, episodes: 200
# 19851: reward: 200.00, mean_100: 131.14, episodes: 201
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 20051: reward: 200.00, mean_100: 131.14, episodes: 202
# 20251: reward: 200.00, mean_100: 132.30, episodes: 203
# 20451: reward: 200.00, mean_100: 133.33, episodes: 204
# 20651: reward: 200.00, mean_100: 134.02, episodes: 205
# 20851: reward: 200.00, mean_100: 134.59, episodes: 206
# 21051: reward: 200.00, mean_100: 134.67, episodes: 207
# 21251: reward: 200.00, mean_100: 135.29, episodes: 208
# 21439: reward: 188.00, mean_100: 135.17, episodes: 209
# 21639: reward: 200.00, mean_100: 135.17, episodes: 210
# 21839: reward: 200.00, mean_100: 135.17, episodes: 211
# 22039: reward: 200.00, mean_100: 135.17, episodes: 212
# 22239: reward: 200.00, mean_100: 135.17, episodes: 213
# 22439: reward: 200.00, mean_100: 135.17, episodes: 214
# 22639: reward: 200.00, mean_100: 135.17, episodes: 215
# 22839: reward: 200.00, mean_100: 135.17, episodes: 216
# 23039: reward: 200.00, mean_100: 135.28, episodes: 217
# 23239: reward: 200.00, mean_100: 135.28, episodes: 218
# 23439: reward: 200.00, mean_100: 135.28, episodes: 219
# 23639: reward: 200.00, mean_100: 135.28, episodes: 220
# 23839: reward: 200.00, mean_100: 135.75, episodes: 221
# 24039: reward: 200.00, mean_100: 136.05, episodes: 222
# 24239: reward: 200.00, mean_100: 136.43, episodes: 223
# 24439: reward: 200.00, mean_100: 136.72, episodes: 224
# 24639: reward: 200.00, mean_100: 137.63, episodes: 225
# 24839: reward: 200.00, mean_100: 138.40, episodes: 226
# 25039: reward: 200.00, mean_100: 139.30, episodes: 227
# 25239: reward: 200.00, mean_100: 140.01, episodes: 228
# 25439: reward: 200.00, mean_100: 140.95, episodes: 229
# 25639: reward: 200.00, mean_100: 141.81, episodes: 230
# 25839: reward: 200.00, mean_100: 143.21, episodes: 231
# 26039: reward: 200.00, mean_100: 144.11, episodes: 232
# 26239: reward: 200.00, mean_100: 145.33, episodes: 233
# 26439: reward: 200.00, mean_100: 146.47, episodes: 234
# 26639: reward: 200.00, mean_100: 147.39, episodes: 235
# 26839: reward: 200.00, mean_100: 148.72, episodes: 236
# 27039: reward: 200.00, mean_100: 150.26, episodes: 237
# 27239: reward: 200.00, mean_100: 151.39, episodes: 238
# 27439: reward: 200.00, mean_100: 152.97, episodes: 239
# 27639: reward: 200.00, mean_100: 154.49, episodes: 240
# 27839: reward: 200.00, mean_100: 155.78, episodes: 241
# 28039: reward: 200.00, mean_100: 157.29, episodes: 242
# 28239: reward: 200.00, mean_100: 158.71, episodes: 243
# 28439: reward: 200.00, mean_100: 160.12, episodes: 244
# 28639: reward: 200.00, mean_100: 161.44, episodes: 245
# 28839: reward: 200.00, mean_100: 162.77, episodes: 246
# 29039: reward: 200.00, mean_100: 163.93, episodes: 247
# 29239: reward: 200.00, mean_100: 165.25, episodes: 248
# 29439: reward: 200.00, mean_100: 166.70, episodes: 249
# 29639: reward: 200.00, mean_100: 168.17, episodes: 250
# 29839: reward: 200.00, mean_100: 169.71, episodes: 251
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 30039: reward: 200.00, mean_100: 171.19, episodes: 252
# 30239: reward: 200.00, mean_100: 172.66, episodes: 253
# 30439: reward: 200.00, mean_100: 173.88, episodes: 254
# 30639: reward: 200.00, mean_100: 175.19, episodes: 255
# 30839: reward: 200.00, mean_100: 176.19, episodes: 256
# 31039: reward: 200.00, mean_100: 177.24, episodes: 257
# 31239: reward: 200.00, mean_100: 178.49, episodes: 258
# 31439: reward: 200.00, mean_100: 179.67, episodes: 259
# 31639: reward: 200.00, mean_100: 181.08, episodes: 260
# 31779: reward: 140.00, mean_100: 181.72, episodes: 261
# 31908: reward: 129.00, mean_100: 182.15, episodes: 262
# 32061: reward: 153.00, mean_100: 182.91, episodes: 263
# 32261: reward: 200.00, mean_100: 184.07, episodes: 264
# 32373: reward: 112.00, mean_100: 184.13, episodes: 265
# 32497: reward: 124.00, mean_100: 184.64, episodes: 266
# 32616: reward: 119.00, mean_100: 184.65, episodes: 267
# 32747: reward: 131.00, mean_100: 184.87, episodes: 268
# 32864: reward: 117.00, mean_100: 184.90, episodes: 269
# 32964: reward: 100.00, mean_100: 184.89, episodes: 270
# 33065: reward: 101.00, mean_100: 184.60, episodes: 271
# 33177: reward: 112.00, mean_100: 184.82, episodes: 272
# 33284: reward: 107.00, mean_100: 184.76, episodes: 273
# 33390: reward: 106.00, mean_100: 184.69, episodes: 274
# 33509: reward: 119.00, mean_100: 184.45, episodes: 275
# 33611: reward: 102.00, mean_100: 184.25, episodes: 276
# 33652: reward:  41.00, mean_100: 182.66, episodes: 277
# 33698: reward:  46.00, mean_100: 181.37, episodes: 278
# 33757: reward:  59.00, mean_100: 180.74, episodes: 279
# 33811: reward:  54.00, mean_100: 180.18, episodes: 280
# 33854: reward:  43.00, mean_100: 178.61, episodes: 281
# 33910: reward:  56.00, mean_100: 177.99, episodes: 282
# 33990: reward:  80.00, mean_100: 176.79, episodes: 283
# 34045: reward:  55.00, mean_100: 175.34, episodes: 284
# 34104: reward:  59.00, mean_100: 174.02, episodes: 285
# 34143: reward:  39.00, mean_100: 172.42, episodes: 286
# 34186: reward:  43.00, mean_100: 170.85, episodes: 287
# 34241: reward:  55.00, mean_100: 169.88, episodes: 288
# 34275: reward:  34.00, mean_100: 168.22, episodes: 289
# 34318: reward:  43.00, mean_100: 166.65, episodes: 290
# 34351: reward:  33.00, mean_100: 164.98, episodes: 291
# 34403: reward:  52.00, mean_100: 163.50, episodes: 292
# 34444: reward:  41.00, mean_100: 161.91, episodes: 293
# 34484: reward:  40.00, mean_100: 160.31, episodes: 294
# 34529: reward:  45.00, mean_100: 158.76, episodes: 295
# 34559: reward:  30.00, mean_100: 157.06, episodes: 296
# 34592: reward:  33.00, mean_100: 155.41, episodes: 297
# 34636: reward:  44.00, mean_100: 153.85, episodes: 298
# 34678: reward:  42.00, mean_100: 152.27, episodes: 299
# 34721: reward:  43.00, mean_100: 150.70, episodes: 300
# 34754: reward:  33.00, mean_100: 149.03, episodes: 301
# 34792: reward:  38.00, mean_100: 147.41, episodes: 302
# 34833: reward:  41.00, mean_100: 145.82, episodes: 303
# 34876: reward:  43.00, mean_100: 144.25, episodes: 304
# 34912: reward:  36.00, mean_100: 142.61, episodes: 305
# 34958: reward:  46.00, mean_100: 141.07, episodes: 306
# 34990: reward:  32.00, mean_100: 139.39, episodes: 307
# 35011: reward:  21.00, mean_100: 137.60, episodes: 308
# 35057: reward:  46.00, mean_100: 136.18, episodes: 309
# 35086: reward:  29.00, mean_100: 134.47, episodes: 310
# 35110: reward:  24.00, mean_100: 132.71, episodes: 311
# 35138: reward:  28.00, mean_100: 130.99, episodes: 312
# 35175: reward:  37.00, mean_100: 129.36, episodes: 313
# 35204: reward:  29.00, mean_100: 127.65, episodes: 314
# 35231: reward:  27.00, mean_100: 125.92, episodes: 315
# 35266: reward:  35.00, mean_100: 124.27, episodes: 316
# 35292: reward:  26.00, mean_100: 122.53, episodes: 317
# 35315: reward:  23.00, mean_100: 120.76, episodes: 318
# 35359: reward:  44.00, mean_100: 119.20, episodes: 319
# 35407: reward:  48.00, mean_100: 117.68, episodes: 320
# 35450: reward:  43.00, mean_100: 116.11, episodes: 321
# 35484: reward:  34.00, mean_100: 114.45, episodes: 322
# 35532: reward:  48.00, mean_100: 112.93, episodes: 323
# 35563: reward:  31.00, mean_100: 111.24, episodes: 324
# 35593: reward:  30.00, mean_100: 109.54, episodes: 325
# 35621: reward:  28.00, mean_100: 107.82, episodes: 326
# 35660: reward:  39.00, mean_100: 106.21, episodes: 327
# 35698: reward:  38.00, mean_100: 104.59, episodes: 328
# 35731: reward:  33.00, mean_100: 102.92, episodes: 329
# 35765: reward:  34.00, mean_100: 101.26, episodes: 330
# 35808: reward:  43.00, mean_100:  99.69, episodes: 331
# 35841: reward:  33.00, mean_100:  98.02, episodes: 332
# 35886: reward:  45.00, mean_100:  96.47, episodes: 333
# 35924: reward:  38.00, mean_100:  94.85, episodes: 334
# 35964: reward:  40.00, mean_100:  93.25, episodes: 335
# 36009: reward:  45.00, mean_100:  91.70, episodes: 336
# 36042: reward:  33.00, mean_100:  90.03, episodes: 337
# 36076: reward:  34.00, mean_100:  88.37, episodes: 338
# 36116: reward:  40.00, mean_100:  86.77, episodes: 339
# 36155: reward:  39.00, mean_100:  85.16, episodes: 340
# 36199: reward:  44.00, mean_100:  83.60, episodes: 341
# 36235: reward:  36.00, mean_100:  81.96, episodes: 342
# 36279: reward:  44.00, mean_100:  80.40, episodes: 343
# 36324: reward:  45.00, mean_100:  78.85, episodes: 344
# 36358: reward:  34.00, mean_100:  77.19, episodes: 345
# 36407: reward:  49.00, mean_100:  75.68, episodes: 346
# 36447: reward:  40.00, mean_100:  74.08, episodes: 347
# 36483: reward:  36.00, mean_100:  72.44, episodes: 348
# 36533: reward:  50.00, mean_100:  70.94, episodes: 349
# 36573: reward:  40.00, mean_100:  69.34, episodes: 350
# 36617: reward:  44.00, mean_100:  67.78, episodes: 351
# 36648: reward:  31.00, mean_100:  66.09, episodes: 352
# 36694: reward:  46.00, mean_100:  64.55, episodes: 353
# 36738: reward:  44.00, mean_100:  62.99, episodes: 354
# 36778: reward:  40.00, mean_100:  61.39, episodes: 355
# 36816: reward:  38.00, mean_100:  59.77, episodes: 356
# 36858: reward:  42.00, mean_100:  58.19, episodes: 357
# 36911: reward:  53.00, mean_100:  56.72, episodes: 358
# 36947: reward:  36.00, mean_100:  55.08, episodes: 359
# 36979: reward:  32.00, mean_100:  53.40, episodes: 360
# 37023: reward:  44.00, mean_100:  52.44, episodes: 361
# 37064: reward:  41.00, mean_100:  51.56, episodes: 362
# 37097: reward:  33.00, mean_100:  50.36, episodes: 363
# 37146: reward:  49.00, mean_100:  48.85, episodes: 364
# 37187: reward:  41.00, mean_100:  48.14, episodes: 365
# 37242: reward:  55.00, mean_100:  47.45, episodes: 366
# 37277: reward:  35.00, mean_100:  46.61, episodes: 367
# 37320: reward:  43.00, mean_100:  45.73, episodes: 368
# 37375: reward:  55.00, mean_100:  45.11, episodes: 369
# 37429: reward:  54.00, mean_100:  44.65, episodes: 370
# 37477: reward:  48.00, mean_100:  44.12, episodes: 371
# 37521: reward:  44.00, mean_100:  43.44, episodes: 372
# 37564: reward:  43.00, mean_100:  42.80, episodes: 373
# 37620: reward:  56.00, mean_100:  42.30, episodes: 374
# 37655: reward:  35.00, mean_100:  41.46, episodes: 375
# 37697: reward:  42.00, mean_100:  40.86, episodes: 376
# 37749: reward:  52.00, mean_100:  40.97, episodes: 377
# 37810: reward:  61.00, mean_100:  41.12, episodes: 378
# 37859: reward:  49.00, mean_100:  41.02, episodes: 379
# 37896: reward:  37.00, mean_100:  40.85, episodes: 380
# 37974: reward:  78.00, mean_100:  41.20, episodes: 381
# 38048: reward:  74.00, mean_100:  41.38, episodes: 382
# 38104: reward:  56.00, mean_100:  41.14, episodes: 383
# 38150: reward:  46.00, mean_100:  41.05, episodes: 384
# 38245: reward:  95.00, mean_100:  41.41, episodes: 385
# 38318: reward:  73.00, mean_100:  41.75, episodes: 386
# 38359: reward:  41.00, mean_100:  41.73, episodes: 387
# 38434: reward:  75.00, mean_100:  41.93, episodes: 388
# 38546: reward: 112.00, mean_100:  42.71, episodes: 389
# 38647: reward: 101.00, mean_100:  43.29, episodes: 390
# 38772: reward: 125.00, mean_100:  44.21, episodes: 391
# 38868: reward:  96.00, mean_100:  44.65, episodes: 392
# 38980: reward: 112.00, mean_100:  45.36, episodes: 393
# 39097: reward: 117.00, mean_100:  46.13, episodes: 394
# 39217: reward: 120.00, mean_100:  46.88, episodes: 395
# 39331: reward: 114.00, mean_100:  47.72, episodes: 396
# 39451: reward: 120.00, mean_100:  48.59, episodes: 397
# 39573: reward: 122.00, mean_100:  49.37, episodes: 398
# 39681: reward: 108.00, mean_100:  50.03, episodes: 399
# 39795: reward: 114.00, mean_100:  50.74, episodes: 400
# 39905: reward: 110.00, mean_100:  51.51, episodes: 401
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 40025: reward: 120.00, mean_100:  52.33, episodes: 402
# 40131: reward: 106.00, mean_100:  52.98, episodes: 403
# 40243: reward: 112.00, mean_100:  53.67, episodes: 404
# 40366: reward: 123.00, mean_100:  54.54, episodes: 405
# 40492: reward: 126.00, mean_100:  55.34, episodes: 406
# 40611: reward: 119.00, mean_100:  56.21, episodes: 407
# 40741: reward: 130.00, mean_100:  57.30, episodes: 408
# 40864: reward: 123.00, mean_100:  58.07, episodes: 409
# 40997: reward: 133.00, mean_100:  59.11, episodes: 410
# 41115: reward: 118.00, mean_100:  60.05, episodes: 411
# 41263: reward: 148.00, mean_100:  61.25, episodes: 412
# 41390: reward: 127.00, mean_100:  62.15, episodes: 413
# 41517: reward: 127.00, mean_100:  63.13, episodes: 414
# 41670: reward: 153.00, mean_100:  64.39, episodes: 415
# 41817: reward: 147.00, mean_100:  65.51, episodes: 416
# 41957: reward: 140.00, mean_100:  66.65, episodes: 417
# 42089: reward: 132.00, mean_100:  67.74, episodes: 418
# 42208: reward: 119.00, mean_100:  68.49, episodes: 419
# 42331: reward: 123.00, mean_100:  69.24, episodes: 420
# 42466: reward: 135.00, mean_100:  70.16, episodes: 421
# 42588: reward: 122.00, mean_100:  71.04, episodes: 422
# 42729: reward: 141.00, mean_100:  71.97, episodes: 423
# 42868: reward: 139.00, mean_100:  73.05, episodes: 424
# 42996: reward: 128.00, mean_100:  74.03, episodes: 425
# 43124: reward: 128.00, mean_100:  75.03, episodes: 426
# 43265: reward: 141.00, mean_100:  76.05, episodes: 427
# 43395: reward: 130.00, mean_100:  76.97, episodes: 428
# 43528: reward: 133.00, mean_100:  77.97, episodes: 429
# 43669: reward: 141.00, mean_100:  79.04, episodes: 430
# 43795: reward: 126.00, mean_100:  79.87, episodes: 431
# 43937: reward: 142.00, mean_100:  80.96, episodes: 432
# 44072: reward: 135.00, mean_100:  81.86, episodes: 433
# 44200: reward: 128.00, mean_100:  82.76, episodes: 434
# 44335: reward: 135.00, mean_100:  83.71, episodes: 435
# 44484: reward: 149.00, mean_100:  84.75, episodes: 436
# 44633: reward: 149.00, mean_100:  85.91, episodes: 437
# 44797: reward: 164.00, mean_100:  87.21, episodes: 438
# 44937: reward: 140.00, mean_100:  88.21, episodes: 439
# 45077: reward: 140.00, mean_100:  89.22, episodes: 440
# 45243: reward: 166.00, mean_100:  90.44, episodes: 441
# 45399: reward: 156.00, mean_100:  91.64, episodes: 442
# 45545: reward: 146.00, mean_100:  92.66, episodes: 443
# 45705: reward: 160.00, mean_100:  93.81, episodes: 444
# 45842: reward: 137.00, mean_100:  94.84, episodes: 445
# 45991: reward: 149.00, mean_100:  95.84, episodes: 446
# 46162: reward: 171.00, mean_100:  97.15, episodes: 447
# 46309: reward: 147.00, mean_100:  98.26, episodes: 448
# 46477: reward: 168.00, mean_100:  99.44, episodes: 449
# 46651: reward: 174.00, mean_100: 100.78, episodes: 450
# 46834: reward: 183.00, mean_100: 102.17, episodes: 451
# 47012: reward: 178.00, mean_100: 103.64, episodes: 452
# 47176: reward: 164.00, mean_100: 104.82, episodes: 453
# 47338: reward: 162.00, mean_100: 106.00, episodes: 454
# 47499: reward: 161.00, mean_100: 107.21, episodes: 455
# 47650: reward: 151.00, mean_100: 108.34, episodes: 456
# 47804: reward: 154.00, mean_100: 109.46, episodes: 457
# 47957: reward: 153.00, mean_100: 110.46, episodes: 458
# 48102: reward: 145.00, mean_100: 111.55, episodes: 459
# 48259: reward: 157.00, mean_100: 112.80, episodes: 460
# 48418: reward: 159.00, mean_100: 113.95, episodes: 461
# 48564: reward: 146.00, mean_100: 115.00, episodes: 462
# 48720: reward: 156.00, mean_100: 116.23, episodes: 463
# 48861: reward: 141.00, mean_100: 117.15, episodes: 464
# 49008: reward: 147.00, mean_100: 118.21, episodes: 465
# 49160: reward: 152.00, mean_100: 119.18, episodes: 466
# 49322: reward: 162.00, mean_100: 120.45, episodes: 467
# 49469: reward: 147.00, mean_100: 121.49, episodes: 468
# 49617: reward: 148.00, mean_100: 122.42, episodes: 469
# 49789: reward: 172.00, mean_100: 123.60, episodes: 470
# 49978: reward: 189.00, mean_100: 125.01, episodes: 471
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 50158: reward: 180.00, mean_100: 126.37, episodes: 472
# 50358: reward: 200.00, mean_100: 127.94, episodes: 473
# 50524: reward: 166.00, mean_100: 129.04, episodes: 474
# 50693: reward: 169.00, mean_100: 130.38, episodes: 475
# 50876: reward: 183.00, mean_100: 131.79, episodes: 476
# 51076: reward: 200.00, mean_100: 133.27, episodes: 477
# 51276: reward: 200.00, mean_100: 134.66, episodes: 478
# 51476: reward: 200.00, mean_100: 136.17, episodes: 479
# 51676: reward: 200.00, mean_100: 137.80, episodes: 480
# 51874: reward: 198.00, mean_100: 139.00, episodes: 481
# 52074: reward: 200.00, mean_100: 140.26, episodes: 482
# 52274: reward: 200.00, mean_100: 141.70, episodes: 483
# 52471: reward: 197.00, mean_100: 143.21, episodes: 484
# 52671: reward: 200.00, mean_100: 144.26, episodes: 485
# 52871: reward: 200.00, mean_100: 145.53, episodes: 486
# 53071: reward: 200.00, mean_100: 147.12, episodes: 487
# 53271: reward: 200.00, mean_100: 148.37, episodes: 488
# 53471: reward: 200.00, mean_100: 149.25, episodes: 489
# 53671: reward: 200.00, mean_100: 150.24, episodes: 490
# 53871: reward: 200.00, mean_100: 150.99, episodes: 491
# 54071: reward: 200.00, mean_100: 152.03, episodes: 492
# 54271: reward: 200.00, mean_100: 152.91, episodes: 493
# 54471: reward: 200.00, mean_100: 153.74, episodes: 494
# 54671: reward: 200.00, mean_100: 154.54, episodes: 495
# 54871: reward: 200.00, mean_100: 155.40, episodes: 496
# 55071: reward: 200.00, mean_100: 156.20, episodes: 497
# 55271: reward: 200.00, mean_100: 156.98, episodes: 498
# 55471: reward: 200.00, mean_100: 157.90, episodes: 499
# 55671: reward: 200.00, mean_100: 158.76, episodes: 500
# 55871: reward: 200.00, mean_100: 159.66, episodes: 501
# 56071: reward: 200.00, mean_100: 160.46, episodes: 502
# 56271: reward: 200.00, mean_100: 161.40, episodes: 503
# 56471: reward: 200.00, mean_100: 162.28, episodes: 504
# 56671: reward: 200.00, mean_100: 163.05, episodes: 505
# 56871: reward: 200.00, mean_100: 163.79, episodes: 506
# 57071: reward: 200.00, mean_100: 164.60, episodes: 507
# 57271: reward: 200.00, mean_100: 165.30, episodes: 508
# 57471: reward: 200.00, mean_100: 166.07, episodes: 509
# 57671: reward: 200.00, mean_100: 166.74, episodes: 510
# 57871: reward: 200.00, mean_100: 167.56, episodes: 511
# 58071: reward: 200.00, mean_100: 168.08, episodes: 512
# 58271: reward: 200.00, mean_100: 168.81, episodes: 513
# 58471: reward: 200.00, mean_100: 169.54, episodes: 514
# 58671: reward: 200.00, mean_100: 170.01, episodes: 515
# 58871: reward: 200.00, mean_100: 170.54, episodes: 516
# 59071: reward: 200.00, mean_100: 171.14, episodes: 517
# 59271: reward: 200.00, mean_100: 171.82, episodes: 518
# 59471: reward: 200.00, mean_100: 172.63, episodes: 519
# 59671: reward: 200.00, mean_100: 173.40, episodes: 520
# 59871: reward: 200.00, mean_100: 174.05, episodes: 521
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 60071: reward: 200.00, mean_100: 174.83, episodes: 522
# 60271: reward: 200.00, mean_100: 175.42, episodes: 523
# 60471: reward: 200.00, mean_100: 176.03, episodes: 524
# 60671: reward: 200.00, mean_100: 176.75, episodes: 525
# 60871: reward: 200.00, mean_100: 177.47, episodes: 526
# 61071: reward: 200.00, mean_100: 178.06, episodes: 527
# 61271: reward: 200.00, mean_100: 178.76, episodes: 528
# 61471: reward: 200.00, mean_100: 179.43, episodes: 529
# 61671: reward: 200.00, mean_100: 180.02, episodes: 530
# 61871: reward: 200.00, mean_100: 180.76, episodes: 531
# 62071: reward: 200.00, mean_100: 181.34, episodes: 532
# 62271: reward: 200.00, mean_100: 181.99, episodes: 533
# 62471: reward: 200.00, mean_100: 182.71, episodes: 534
# 62671: reward: 200.00, mean_100: 183.36, episodes: 535
# 62871: reward: 200.00, mean_100: 183.87, episodes: 536
# 63071: reward: 200.00, mean_100: 184.38, episodes: 537
# 63271: reward: 200.00, mean_100: 184.74, episodes: 538
# 63471: reward: 200.00, mean_100: 185.34, episodes: 539
# 63671: reward: 200.00, mean_100: 185.94, episodes: 540
# 63871: reward: 200.00, mean_100: 186.28, episodes: 541
# 64071: reward: 200.00, mean_100: 186.72, episodes: 542
# 64271: reward: 200.00, mean_100: 187.26, episodes: 543
# 64471: reward: 200.00, mean_100: 187.66, episodes: 544
# 64671: reward: 200.00, mean_100: 188.29, episodes: 545
# 64871: reward: 200.00, mean_100: 188.80, episodes: 546
# 65071: reward: 200.00, mean_100: 189.09, episodes: 547
# 65271: reward: 200.00, mean_100: 189.62, episodes: 548
# 65471: reward: 200.00, mean_100: 189.94, episodes: 549
# 65671: reward: 200.00, mean_100: 190.20, episodes: 550
# 65871: reward: 200.00, mean_100: 190.37, episodes: 551
# 66071: reward: 200.00, mean_100: 190.59, episodes: 552
# 66271: reward: 200.00, mean_100: 190.95, episodes: 553
# 66471: reward: 200.00, mean_100: 191.33, episodes: 554
# 66671: reward: 200.00, mean_100: 191.72, episodes: 555
# 66871: reward: 200.00, mean_100: 192.21, episodes: 556
# 67071: reward: 200.00, mean_100: 192.67, episodes: 557
# 67271: reward: 200.00, mean_100: 193.14, episodes: 558
# 67471: reward: 200.00, mean_100: 193.69, episodes: 559
# 67671: reward: 200.00, mean_100: 194.12, episodes: 560
# 67871: reward: 200.00, mean_100: 194.53, episodes: 561
# 68071: reward: 200.00, mean_100: 195.07, episodes: 562
# Solved in 68071 steps and 562 episodes!

# %%
logs_base_dir = "./runs"
# %tensorboard --logdir {logs_base_dir}

# %%
print(env.observation_space)

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
